# %% [markdown]
# 1) сглаживание
# gi - старое значение яркости
# n = размер ядра свертки
# n (яркость) = 0...255, n - ширина фильтра сглаживания
#
# берем кол0во пикселей с нулевой яркостью n/2 соседей слева и справа соседей слева если не хватает дополняем нулями, складываем колво пикселей с нулевой яркостью и в новую
# взвешенная сумма значений
# Если выходим за границу дополняем нулями
#
# 2) Найти лок минимумы:
# на концах и по серединке
#
# чтобы найти лок минимум - надо взять точку где прав  левый сосед больше
# шаг при проверке 1
#
# 3) однородные обл окрасить в псевдоцвета
# взять пиксели одного сегмента и закрасить в один цвет
# цвета выбирают саи (генерируют рандомный или берут список и из списка по очереди выбирают цвета)
#
# подпись слева, он меньше и темнее
